# %% [markdown]
# # Phase 0: CSS Class Inventory for Tharpa Publications EPUBs
#
# **PURPOSE**: Systematically document ALL CSS classes used in the EPUB to answer:
# 1. What classes are used for chapter titles?
# 2. What classes are used for section headings?
# 3. What classes are used for body paragraphs?
# 4. Are there multiple heading levels?
# 5. What other structural classes exist?
#
# **Run this BEFORE any re-extraction work.**
#
# Output: `00_css_class_inventory.json` (machine-readable inventory)

# %%
# ============================================================
# CONFIGURATION - Update this path for your system
# ============================================================
import os

EPUB_DIR = os.path.expanduser("~/Documents/gesha_la_rag/epub_directory/")
EPUB_FILE = "Clear_Light_of_Bliss.epub"
EPUB_PATH = os.path.join(EPUB_DIR, EPUB_FILE)
OUTPUT_FILE = "00_css_class_inventory.json"

print(f"Target: {EPUB_PATH}")
print(f"Exists: {os.path.exists(EPUB_PATH)}")
# Out:
# Target: /home/matt/Documents/gesha_la_rag/epub_directory/Clear_Light_of_Bliss.epub
# Exists: True

# %%
import ebooklib
from ebooklib import epub
from bs4 import BeautifulSoup
from collections import Counter, defaultdict
import json
import re

book = epub.read_epub(EPUB_PATH)
items = list(book.get_items_of_type(ebooklib.ITEM_DOCUMENT))

print(f"✓ EPUB loaded successfully")
try:
    title = book.get_metadata('DC', 'title')
    print(f"Title: {title[0][0] if title else 'Unknown'}")
except:
    print("Title: Unable to extract")
print(f"✓ Found {len(items)} document sections")
# Out:
# ✓ EPUB loaded successfully
# Title: Clear Light of Bliss
# ✓ Found 89 document sections

# %% [markdown]
# ## Helper Functions
#
# `classify_css_role()` uses heuristic matching on class name patterns. If Tharpa uses unexpected naming, unmatched classes will appear as UNKNOWN — that's by design so we can review them.

# %%
def classify_css_role(class_name):
    """
    Heuristic classification of CSS class names into structural roles.
    Returns a guessed role based on naming patterns.
    """
    cl = class_name.lower()
    
    # Chapter-level headings
    if any(x in cl for x in ['chapter-title', 'chapter_title', 'chaptertitle']):
        return 'CHAPTER_TITLE'
    if any(x in cl for x in ['part-title', 'part_title', 'parttitle']):
        return 'PART_TITLE'
    
    # Section headings  
    if any(x in cl for x in ['section-head', 'section_head', 'sectionhead',
                               'sub-head', 'sub_head', 'subhead']):
        return 'SECTION_HEADING'
    if 'head' in cl and 'chapter' not in cl:
        return 'HEADING_OTHER'
    
    # Body text
    if any(x in cl for x in ['text-1st', 'text_1st', 'first-para', 'first_para']):
        return 'BODY_FIRST_PARA'
    if cl.startswith('text') or 'body' in cl or 'para' in cl:
        return 'BODY_TEXT'
    
    # Special content
    if any(x in cl for x in ['verse', 'poem', 'stanza', 'dedication']):
        return 'VERSE_POETRY'
    if any(x in cl for x in ['quote', 'block', 'extract', 'indent']):
        return 'BLOCK_QUOTE'
    if any(x in cl for x in ['footnote', 'endnote', 'note']):
        return 'FOOTNOTE'
    if any(x in cl for x in ['toc', 'contents']):
        return 'TABLE_OF_CONTENTS'
    if any(x in cl for x in ['copyright', 'colophon', 'imprint']):
        return 'FRONT_MATTER'
    if any(x in cl for x in ['glossary', 'index', 'appendix', 'bibliography']):
        return 'BACK_MATTER'
    if any(x in cl for x in ['image', 'figure', 'caption', 'illustration']):
        return 'IMAGE_CAPTION'
    if any(x in cl for x in ['list', 'bullet', 'enum']):
        return 'LIST'
    
    return 'UNKNOWN'


def extract_heading_level(class_name):
    """
    Try to extract a heading level number from the class name.
    e.g., 'TOC-Level-1' -> 1, 'Section-Head-2' -> 2
    """
    cl = class_name.lower()
    for pat in [r'level[_-]?(\d+)', r'head[_-]?(\d+)', r'-(\d+)$']:
        m = re.search(pat, cl)
        if m:
            return int(m.group(1))
    return None

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## Pass 1: Collect ALL CSS Classes
#
# Scan every element in every section of the EPUB. Record class names, which HTML tags use them, how often they appear, and sample text content.

# %%
# Data structures
class_counter = Counter()           # class_name -> total occurrences
class_by_tag = defaultdict(Counter)  # tag -> {class_name -> count}
class_samples = defaultdict(list)    # class_name -> [sample texts]
class_sections = defaultdict(set)    # class_name -> {section_names}
all_tags_used = Counter()            # tag -> count
classes_by_section = {}              # section_name -> [classes found]

MAX_SAMPLES = 3
SAMPLE_MAX_LEN = 120

for idx, item in enumerate(items):
    section_name = item.get_name()
    content = item.get_content()
    soup = BeautifulSoup(content, 'html.parser')
    
    section_classes = set()
    
    for element in soup.find_all(True):  # True = all tags
        tag_name = element.name
        all_tags_used[tag_name] += 1
        
        classes = element.get('class', [])
        if classes:
            for cls in classes:
                class_counter[cls] += 1
                class_by_tag[tag_name][cls] += 1
                class_sections[cls].add(section_name)
                section_classes.add(cls)
                
                # Collect sample text
                if len(class_samples[cls]) < MAX_SAMPLES:
                    text = element.get_text(strip=True)
                    if text:
                        sample = text[:SAMPLE_MAX_LEN]
                        if len(text) > SAMPLE_MAX_LEN:
                            sample += "..."
                        class_samples[cls].append({
                            'text': sample,
                            'section': section_name,
                            'section_idx': idx
                        })
    
    classes_by_section[section_name] = sorted(section_classes)

print(f"✓ Scanned {len(items)} sections")
print(f"✓ Found {len(class_counter)} unique CSS classes")
print(f"✓ HTML tags used: {', '.join(f'{t}({c})' for t, c in all_tags_used.most_common(10))}")
# Out:
# ✓ Scanned 89 sections
# ✓ Found 121 unique CSS classes
# ✓ HTML tags used: a(4019), p(3529), span(992), div(299), html(89), head(89), body(89), img(37), li(35), nav(2)

# %% [markdown]
# ## Pass 2: Classify by Structural Role

# %%
classified = defaultdict(list)

for cls, count in class_counter.most_common():
    role = classify_css_role(cls)
    level = extract_heading_level(cls)
    
    tag_list = []
    for tag in class_by_tag:
        if cls in class_by_tag[tag]:
            tag_list.append(f"{tag}({class_by_tag[tag][cls]})")
    
    info = {
        'class_name': cls,
        'count': count,
        'role': role,
        'heading_level': level,
        'tags': tag_list,
        'sections_count': len(class_sections[cls]),
        'samples': class_samples.get(cls, [])
    }
    classified[role].append(info)

print("Classes by role:")
for role, items_list in sorted(classified.items(), key=lambda x: -sum(i['count'] for i in x[1])):
    total = sum(i['count'] for i in items_list)
    print(f"  {role}: {len(items_list)} classes, {total} total occurrences")
# Out:
# Classes by role:
#   UNKNOWN: 47 classes, 1475 total occurrences
#   BACK_MATTER: 8 classes, 1238 total occurrences
#   BODY_TEXT: 33 classes, 1053 total occurrences
#   VERSE_POETRY: 6 classes, 352 total occurrences
#   BODY_FIRST_PARA: 4 classes, 251 total occurrences
#   HEADING_OTHER: 6 classes, 146 total occurrences
#   IMAGE_CAPTION: 6 classes, 57 total occurrences
#   CHAPTER_TITLE: 3 classes, 36 total occurrences
#   SECTION_HEADING: 1 classes, 23 total occurrences
#   FRONT_MATTER: 1 classes, 6 total occurrences
#   LIST: 2 classes, 6 total occurrences
#   BLOCK_QUOTE: 4 classes, 4 total occurrences

# %% [markdown]
# ## Results: Full CSS Class Inventory
#
# Every class found, grouped by structural role, with sample text for verification.

# %%
role_order = [
    'CHAPTER_TITLE', 'PART_TITLE', 'SECTION_HEADING', 'HEADING_OTHER',
    'BODY_FIRST_PARA', 'BODY_TEXT', 'VERSE_POETRY', 'BLOCK_QUOTE',
    'TABLE_OF_CONTENTS', 'FRONT_MATTER', 'BACK_MATTER',
    'FOOTNOTE', 'IMAGE_CAPTION', 'LIST', 'UNKNOWN'
]

for role in role_order:
    if role not in classified:
        continue
    items_in_role = classified[role]
    
    print(f"\n{'─' * 70}")
    print(f"  {role} ({len(items_in_role)} classes)")
    print(f"{'─' * 70}")
    
    for info in sorted(items_in_role, key=lambda x: -x['count']):
        level_str = f" [Level {info['heading_level']}]" if info['heading_level'] else ""
        print(f"\n  📌 {info['class_name']}{level_str}")
        print(f"     Count: {info['count']} | In {info['sections_count']} sections | Tags: {', '.join(info['tags'])}")
        
        for sample in info['samples'][:2]:
            print(f'     Sample: "{sample["text"]}"')
            print(f"             (section {sample['section_idx']}: {sample['section']})")
# Out:
# ──────────────────────────────────────────────────────────────────────
#   CHAPTER_TITLE (3 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Chapter-title-TOC-Level-1 [Level 1]
#      Count: 30 | In 30 sections | Tags: p(30)
#      Sample: "About the Author"
#              (section 2: Clear_Light_of_Bliss_Text_2019-08-1.xhtml)
#      Sample: "Contents"
#              (section 6: Clear_Light_of_Bliss_Text_2019-08-5.xhtml)
#
#   📌 Chapter-title-TOC-Level-2 [Level 2]
#      Count: 4 | In 4 sections | Tags: p(4)
#      Sample: "The Condensed Meaning of the Text"
#              (section 69: Clear_Light_of_Bliss_Text_2019-08-68.xhtml)
#      Sample: "Prayers of Request to the Mahamudra Lineage Gurus"
#              (section 73: Clear_Light_of_Bliss_Text_2019-08-72.xhtml)
#
#   📌 Chapter-title-TOC-Level-1-no-new-page [Level 1]
#      Count: 2 | In 2 sections | Tags: p(2)
#      Sample: "Foreword"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "Study Programmes of Kadampa Buddhism"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   SECTION_HEADING (1 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Index-Section-Head
#      Count: 23 | In 1 sections | Tags: p(23)
#      Sample: "A"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "B"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   HEADING_OTHER (6 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Text-heading-1 [Level 1]
#      Count: 101 | In 22 sections | Tags: p(101)
#      Sample: "AN INTRODUCTION TO THE GENERAL PATHS"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "THE SOURCE OF THE LINEAGE FROM WHICH THESE INSTRUCTIONS ARE DERIVED"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Sadhana-heading-3 [Level 3]
#      Count: 13 | In 2 sections | Tags: p(13)
#      Sample: "Going for refuge"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "Generating the supreme good heart, bodhichitta"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Text-heading-3-italics-brackets
#      Count: 12 | In 1 sections | Tags: p(12)
#      Sample: "(1) An illusion"
#              (section 61: Clear_Light_of_Bliss_Text_2019-08-60.xhtml)
#      Sample: "(2) A reflection of the moon in water"
#              (section 61: Clear_Light_of_Bliss_Text_2019-08-60.xhtml)
#
#   📌 Sadhana-heading-4 [Level 4]
#      Count: 9 | In 1 sections | Tags: p(9)
#      Sample: "Visualization and Meditation"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "Inviting the Wisdom Beings"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Sadhana-heading-2 [Level 2]
#      Count: 8 | In 6 sections | Tags: p(8)
#      Sample: "THE MAHAMUDRA OF THE ORAL LINEAGE OF THE UNEQUALLED VIRTUOUS TRADITION"
#              (section 68: Clear_Light_of_Bliss_Text_2019-08-67.xhtml)
#      Sample: "CONTENTS"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#
#   📌 Sadhana-heading-3-centre
#      Count: 3 | In 1 sections | Tags: p(3)
#      Sample: "GENERAL PROGRAMME"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "FOUNDATION PROGRAMME"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   BODY_FIRST_PARA (4 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Text-1st-para-space-below
#      Count: 101 | In 20 sections | Tags: p(101)
#      Sample: "It is very pleasing to have this opportunity to explain the method for practising Vajrayana Mahamudra according to theMa..."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "InGuide to the Bodhisattva’s Way of LifeShantideva says:"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-1st-para
#      Count: 100 | In 32 sections | Tags: p(100)
#      Sample: "Geshe Kelsang Gyatso is a fully accomplished meditation master and internationally renowned teacher of Buddhism who has ..."
#              (section 2: Clear_Light_of_Bliss_Text_2019-08-1.xhtml)
#      Sample: "YongdzinLing Rinpoche"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#
#   📌 Text-1st-para-full-space-below
#      Count: 47 | In 17 sections | Tags: p(47)
#      Sample: "May virtue and excellence increase."
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "If an explanation of these four were given here, this text would become too long. Those who are seriously interested in ..."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Sadhana-instruction-first-para
#      Count: 3 | In 2 sections | Tags: p(3)
#      Sample: "At this point, (1) while experiencing great bliss and emptiness, (2) we meditate on the clear appearance of the mandala ..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "Recite at least as many mantras as you have promised."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   BODY_TEXT (33 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Text-2nd-para
#      Count: 383 | In 31 sections | Tags: p(383)
#      Sample: "Find our more atwww.tharpa.com"
#              (section 2: Clear_Light_of_Bliss_Text_2019-08-1.xhtml)
#      Sample: "I am very happy to learn that Venerable Geshe Kelsang Gyatso has given extensive teachings on Secret Mantra based on Pro..."
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#
#   📌 Text-list-10-to-99-with-parenthesis-middle
#      Count: 92 | In 2 sections | Tags: p(92)
#      Sample: "(10)	The eyesense power"
#              (section 35: Clear_Light_of_Bliss_Text_2019-08-34.xhtml)
#      Sample: "(11)	The ear sense power"
#              (section 35: Clear_Light_of_Bliss_Text_2019-08-34.xhtml)
#
#   📌 Text-list-1-to-9-middle
#      Count: 86 | In 14 sections | Tags: p(86)
#      Sample: "2	The source of the lineage from which these instructions are derived"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "1	The preliminary practices"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-list-1-to-9-last-full-space-below
#      Count: 59 | In 15 sections | Tags: p(59)
#      Sample: "3	The actual explanation of the instructions possessing this lineage"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "3	The concluding stages"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-list-1-to-9-with-parenthesis-middle
#      Count: 58 | In 5 sections | Tags: p(58)
#      Sample: "(2)	All contaminated things are the nature of suffering"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "(3)	All phenomena are selfless"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-2nd-para-full-space-below
#      Count: 58 | In 22 sections | Tags: p(58)
#      Sample: "The second stage of causal-time Mahamudra is the Mahamudra that is theunion of the two truths: the conventional and the ..."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "Prayers of Request to the Mahamudra Lineage Guruscan be found in Appendix II. If we are sincerely interested in studying..."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-list-1-to-9-begin
#      Count: 49 | In 12 sections | Tags: p(49)
#      Sample: "1	An introduction to the general paths"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "1	The guide of going forrefuge and generatingbodhichitta, the gateway to theBuddhadharma and theMahayana."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Text-quotation-verse-middle
#      Count: 44 | In 4 sections | Tags: p(44)
#      Sample: "By depending upon this boat-like human form,"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "We can cross the great ocean of suffering."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-2nd-para-space-below
#      Count: 38 | In 18 sections | Tags: p(38)
#      Sample: "May these teachings, originally given at Manjushri Centre in England and now made available in this book,Clear Light of ..."
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "We also thank all the dedicated, senior Dharma students who assisted the author with the rendering of the English and wh..."
#              (section 9: Clear_Light_of_Bliss_Text_2019-08-8.xhtml)
#
#   📌 TOC-Body-Text
#      Count: 32 | In 1 sections | Tags: p(32)
#      Sample: "Suggested study or reading order for beginners of books by Venerable Geshe Kelsang Gyatso Rinpoche"
#              (section 6: Clear_Light_of_Bliss_Text_2019-08-5.xhtml)
#      Sample: "About the Author"
#              (section 6: Clear_Light_of_Bliss_Text_2019-08-5.xhtml)
#
#   📌 Text-list-1-to-9-with-parenthesis-begin
#      Count: 26 | In 7 sections | Tags: p(26)
#      Sample: "(1)	All products are impermanent"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "(1)	The upper tip of the centralchannel: thepoint between the eyebrows"
#              (section 16: Clear_Light_of_Bliss_Text_2019-08-15.xhtml)
#
#   📌 Text-quotation-verse-italic-begin
#      Count: 15 | In 4 sections | Tags: p(15)
#      Sample: "For the sake of all sentient beings"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "Eternally I shall go for refuge"
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Text-quotation-prose-single
#      Count: 15 | In 7 sections | Tags: p(15)
#      Sample: "Now I have become the actualEnjoyment Body Buddha Heruka."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#      Sample: "Instantly my mind, in the form of a beam of blue light, transforms into Heruka, blue in colour with one face and two arm..."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Text-list-10-to-99-with-parenthesis-last
#      Count: 15 | In 4 sections | Tags: p(15)
#      Sample: "(10)	The wheel of fire: the centre of thechannel wheel located midway between the throat and the heartchannel wheels, ha..."
#              (section 16: Clear_Light_of_Bliss_Text_2019-08-15.xhtml)
#      Sample: "(10)	The definitely-moving wind"
#              (section 21: Clear_Light_of_Bliss_Text_2019-08-20.xhtml)
#
#   📌 Text-quotation-verse-italic-middle
#      Count: 12 | In 3 sections | Tags: p(12)
#      Sample: "I will drink the nectar of this instruction"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "So that I may attain Buddhahood within this life"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Text-list-1-to-9-with-parenthesis-last
#      Count: 12 | In 6 sections | Tags: p(12)
#      Sample: "(4)	Onlynirvana is peace"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "(5)	Thepervading wind"
#              (section 21: Clear_Light_of_Bliss_Text_2019-08-20.xhtml)
#
#   📌 Text-Signature-Author-2-lines-plus
#      Count: 9 | In 3 sections | Tags: p(9)
#      Sample: "Roy Tyson,"
#              (section 9: Clear_Light_of_Bliss_Text_2019-08-8.xhtml)
#      Sample: "Administrative Director,"
#              (section 9: Clear_Light_of_Bliss_Text_2019-08-8.xhtml)
#
#   📌 Text-quotation-verse-last
#      Count: 7 | In 4 sections | Tags: p(7)
#      Sample: "This is no time to sleep, you fool!"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "Dorjechang Kelsang Gyatso Rinpoche"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#
#   📌 Sadhana-instruction-middle-para
#      Count: 6 | In 2 sections | Tags: p(6)
#      Sample: "In this way we train sincerely in one single meditation ongeneration stage possessing these three characteristics. Holdi..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "If we wish to practise completion stage meditation, we should change ourself through imagination from Heruka with four f..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Text-quotation-verse-italic-last
#      Count: 4 | In 3 sections | Tags: p(4)
#      Sample: "Through the profound path of Secret Mantra."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "I shall become Heruka."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Text-quotation-verse-begin
#      Count: 4 | In 4 sections | Tags: p(4)
#      Sample: "Vajradhara"
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "Do not rely upon the person, but upon theDharma."
#              (section 47: Clear_Light_of_Bliss_Text_2019-08-46.xhtml)
#
#   📌 Text-list-1-to-9-last
#      Count: 4 | In 4 sections | Tags: p(4)
#      Sample: "4	The guide ofGuru yoga, the gateway to receivingblessings."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#      Sample: "8	An explanation of extraordinary blazing and dripping"
#              (section 27: Clear_Light_of_Bliss_Text_2019-08-26.xhtml)
#
#   📌 Text-title-2 [Level 2]
#      Count: 4 | In 4 sections | Tags: p(4)
#      Sample: "CHART 1  THE FOUR MAJOR CHANNEL WHEELS"
#              (section 17: Clear_Light_of_Bliss_Text_2019-08-16.xhtml)
#      Sample: "CHART 2:  THE SPOKES OF THE HEARTCHANNEL WHEEL"
#              (section 20: Clear_Light_of_Bliss_Text_2019-08-19.xhtml)
#
#   📌 Study-program-text-2nd-para
#      Count: 4 | In 1 sections | Tags: p(4)
#      Sample: "The lineage of these teachings, both their oral transmission and blessings, was then passed from Teacher to disciple, sp..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "Kadampa Buddhism was first introduced to the modern world in 1977 by the renowned Buddhist Master, Venerable Geshe Kelsa..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Text-quotation-prose-single-last
#      Count: 3 | In 1 sections | Tags: p(3)
#      Sample: "All worlds and their beings melt into blue light, which then dissolves into me. My body gradually melts into light simul..."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#      Sample: "This is me; I am the actual Truth Body Buddha Heruka."
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Sadhana-instruction-last-para
#      Count: 3 | In 2 sections | Tags: p(3)
#      Sample: "Then, when we need to rest from meditation, we can practise mantra recitation."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "The ‘three-OM’ mantra is the union of the essence and close essence mantras of Vajravarahi. The meaning of this mantra i..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Text-quotation-verse-single
#      Count: 2 | In 2 sections | Tags: p(2)
#      Sample: "The nature of all phenomena is the great seal."
#              (section 12: Clear_Light_of_Bliss_Text_2019-08-11.xhtml)
#      Sample: "Do not accept my teachings simply because I am called Buddha."
#              (section 47: Clear_Light_of_Bliss_Text_2019-08-46.xhtml)
#
#   📌 Text-quotation-prose-single-full-space-below
#      Count: 2 | In 2 sections | Tags: p(2)
#      Sample: "Inner fire meditation is like a wishfulfilling cow, from which we can receive an inexhaustible supply of nourishment."
#              (section 31: Clear_Light_of_Bliss_Text_2019-08-30.xhtml)
#      Sample: "The practice of Secret Mantra begins with generation stage, whereby I preventordinary appearance of myself and of all ot..."
#              (section 59: Clear_Light_of_Bliss_Text_2019-08-58.xhtml)
#
#   📌 Text-list-1-to-9-with-parenthesis-last-full-space-below
#      Count: 2 | In 2 sections | Tags: p(2)
#      Sample: "(3)	How Buddhahood is attained in a place that is neither"
#              (section 65: Clear_Light_of_Bliss_Text_2019-08-64.xhtml)
#      Sample: "2	To strive to maintain purely all the vows we have taken"
#              (section 78: Clear_Light_of_Bliss_Text_2019-08-77.xhtml)
#
#   📌 Study-program-text-2nd-para-full-space-below
#      Count: 2 | In 1 sections | Tags: p(2)
#      Sample: "Venerable Geshe Kelsang, or ‘Geshe-la’ as he is affectionately called by his students, has designed three special spirit..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "A Special Teacher Training Programme is also held at Manjushri Kadampa Meditation Centre, Ulverston, England, and can be..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Text-quotation-verse-italic-last-full-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "And unceasingly performing enlightened deeds."
#              (section 67: Clear_Light_of_Bliss_Text_2019-08-66.xhtml)
#
#   📌 Text-quotation-verse-italic-single
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "May everything be auspicious."
#              (section 67: Clear_Light_of_Bliss_Text_2019-08-66.xhtml)
#
#   📌 Text-quotation-verse-last-full-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "May everything be auspicious."
#              (section 69: Clear_Light_of_Bliss_Text_2019-08-68.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   VERSE_POETRY (6 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Sadhana-verse-middle
#      Count: 264 | In 4 sections | Tags: p(264)
#      Sample: "With great respect and devotion I rely upon Losang Dragpa,"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "Who alone is the precious eyes for countless migrators,"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#
#   📌 Sadhana-verse-last
#      Count: 52 | In 4 sections | Tags: p(52)
#      Sample: "OMBliss and Excellence"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "And holder of three immaculate sets of vows."
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#
#   📌 Sadhana-verse-Liberating-Prayer-middle
#      Count: 16 | In 1 sections | Tags: p(16)
#      Sample: "O Blessed One, Shakyamuni Buddha,"
#              (section 71: Clear_Light_of_Bliss_Text_2019-08-70.xhtml)
#      Sample: "Precious treasury of compassion,"
#              (section 71: Clear_Light_of_Bliss_Text_2019-08-70.xhtml)
#
#   📌 Sadhana-verse-last-full-space-below
#      Count: 9 | In 2 sections | Tags: p(9)
#      Sample: "Homage to the Mahamudra"
#              (section 73: Clear_Light_of_Bliss_Text_2019-08-72.xhtml)
#      Sample: "Through your blessings may they become inseparably one."
#              (section 73: Clear_Light_of_Bliss_Text_2019-08-72.xhtml)
#
#   📌 Sadhana-verse-Liberating-Prayer-last
#      Count: 8 | In 1 sections | Tags: p(8)
#      Sample: "Bestower of supreme inner peace,"
#              (section 71: Clear_Light_of_Bliss_Text_2019-08-70.xhtml)
#      Sample: "And you guide us to the liberating path."
#              (section 71: Clear_Light_of_Bliss_Text_2019-08-70.xhtml)
#
#   📌 Sadhana-verse-x3-full-space-below
#      Count: 3 | In 1 sections | Tags: p(3)
#      Sample: "(21x, 100x, etc.)"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "(7x, 21x, 100x, etc.)"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   BLOCK_QUOTE (4 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Sadhana-Mantra-indent-full-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "IDAM GURU RATNA MANDALAKAM NIRYATAYAMI"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Sadhana-Mantra-indent
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "OM SHRI VAJRA HE HE RU RU KAM HUM HUM PHAT DAKINI DZALA SHAMBARAM SOHA"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Sadhana-Mantra-indent-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "OM OM OM SARWA BUDDHA DAKINIYE VAJRA WARNANIYE VAJRA BEROTZANIYE HUM HUM HUM PHAT PHAT PHAT SOHA"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Sadhana-Mantra-no-indent
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "OM HUM BAM RIM RIM LIM LIM, KAM KHAM GAM GHAM NGAM, TSAM TSHAM DZAM DZHAM NYAM, TrAM THrAM DrAM DHrAM NAM, TAM THAM DAM ..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   FRONT_MATTER (1 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Sadhana-colophon
#      Count: 6 | In 5 sections | Tags: p(6)
#      Sample: "This book,Clear Light of Bliss, is the teachings of Venerable Geshe Kelsang Gyatso Rinpoche. These teachings were record..."
#              (section 67: Clear_Light_of_Bliss_Text_2019-08-66.xhtml)
#      Sample: "Colophon:This condensed meaning, or outline, ofClear Light of Bliss, a commentary to the practice of Mahamudra in Vajray..."
#              (section 69: Clear_Light_of_Bliss_Text_2019-08-68.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   BACK_MATTER (8 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Index-level-1 [Level 1]
#      Count: 412 | In 1 sections | Tags: p(412)
#      Sample: "action mudra111,119–120,"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "Action Tantra4"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Index-level-3 [Level 3]
#      Count: 399 | In 1 sections | Tags: p(399)
#      Sample: "152–154,155,237,250,263,"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "266,267"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Index-level-2 [Level 2]
#      Count: 252 | In 1 sections | Tags: p(252)
#      Sample: "as external method for"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "texts134,140,163,224,225,"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Glossary-entry
#      Count: 153 | In 1 sections | Tags: p(153)
#      Sample: "AggregateIn general, all functioning things are aggregates because they are an aggregation of their parts. In particular..."
#              (section 80: Clear_Light_of_Bliss_Text_2019-08-79.xhtml)
#      Sample: "AlertnessA mental factor which is a type of wisdom that examines our activity of body, speech and mind, and knows whethe..."
#              (section 80: Clear_Light_of_Bliss_Text_2019-08-79.xhtml)
#
#   📌 Index-level-1-space-below [Level 1]
#      Count: 9 | In 1 sections | Tags: p(9)
#      Sample: "attachment5,173,177,180"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "cyclic existence.Seesamsara"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Index-level-3-space-below [Level 3]
#      Count: 9 | In 1 sections | Tags: p(9)
#      Sample: "Body; Truth Body"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "light"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Index-level-2-space-below [Level 2]
#      Count: 3 | In 1 sections | Tags: p(3)
#      Sample: "illustration319"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#      Sample: "of impure winds45–46"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
#   📌 Index-Text
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "The letter ‘g’ indicates an entry in the glossary"
#              (section 84: Clear_Light_of_Bliss_Text_2019-08-83.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   IMAGE_CAPTION (6 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Image-caption
#      Count: 27 | In 27 sections | Tags: p(27)
#      Sample: "Vajradhara"
#              (section 11: Clear_Light_of_Bliss_Text_2019-08-10.xhtml)
#      Sample: "Manjushri"
#              (section 13: Clear_Light_of_Bliss_Text_2019-08-12.xhtml)
#
#   📌 Illustration-entry
#      Count: 26 | In 1 sections | Tags: p(26)
#      Sample: "Vajradhara"
#              (section 7: Clear_Light_of_Bliss_Text_2019-08-6.xhtml)
#      Sample: "Manjushri"
#              (section 7: Clear_Light_of_Bliss_Text_2019-08-6.xhtml)
#
#   📌 Author-Colour-Image
#      Count: 1 | In 1 sections | Tags: div(1)
#
#   📌 tharpa-logo-image
#      Count: 1 | In 1 sections | Tags: div(1)
#
#   📌 nkt-logo-back-image
#      Count: 1 | In 1 sections | Tags: div(1)
#
#   📌 temple-image
#      Count: 1 | In 1 sections | Tags: div(1)
#
# ──────────────────────────────────────────────────────────────────────
#   LIST (2 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Study-Program-List-middle
#      Count: 5 | In 1 sections | Tags: p(5)
#      Sample: "1Joyful Path of Good Fortune– a commentary to Atisha’s Lamrim instructions, the stages of the path to enlightenment."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "2Universal Compassion– a commentary to Bodhisattva Chekhawa’sTraining the Mind in Seven Points."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Study-Program-List-last
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "6How to Understand the Mind– a detailed explanation of the mind, based on the works of the Buddhist scholars Dharmakirti..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
# ──────────────────────────────────────────────────────────────────────
#   UNKNOWN (47 classes)
# ──────────────────────────────────────────────────────────────────────
#
#   📌 Italic
#      Count: 520 | In 30 sections | Tags: span(520)
#      Sample: "included at the request of faithful disciples"
#              (section 7: Clear_Light_of_Bliss_Text_2019-08-6.xhtml)
#      Sample: "Clear Light of Bliss"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#
#   📌 Bold-Italic
#      Count: 236 | In 3 sections | Tags: span(236)
#      Sample: "Migtsema"
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "Aggregate"
#              (section 80: Clear_Light_of_Bliss_Text_2019-08-79.xhtml)
#
#   📌 Small-Caps
#      Count: 135 | In 14 sections | Tags: span(135)
#      Sample: "OM"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "HUM"
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Tharpa-Offices-Address
#      Count: 87 | In 1 sections | Tags: p(87)
#      Sample: "Conishead Priory,"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#      Sample: "ULVERSTON,"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#
#   📌 Biblio-entry-2-lines
#      Count: 73 | In 1 sections | Tags: p(73)
#      Sample: "The Bodhisattva VowA practical guide to helping others. (2nd. edn., 1995)"
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#      Sample: "Clear Light of BlissTantric meditation manual. (3rd. edn., 2014)"
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#
#   📌 Basic-Text-Frame
#      Count: 64 | In 53 sections | Tags: div(64)
#      Sample: "Suggested study or reading order for beginners of books by Venerable Geshe Kelsang Gyatso RinpocheHow to Transform Your ..."
#              (section 3: Clear_Light_of_Bliss_Text_2019-08-2.xhtml)
#      Sample: "Venerable Geshe Kelsang Gyatso Rinpoche"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 ebook-page-break
#      Count: 48 | In 48 sections | Tags: p(48)
#      Sample: "page break"
#              (section 8: Clear_Light_of_Bliss_Text_2019-08-7.xhtml)
#      Sample: "page break"
#              (section 11: Clear_Light_of_Bliss_Text_2019-08-10.xhtml)
#
#   📌 Bold
#      Count: 35 | In 11 sections | Tags: span(35)
#      Sample: "The five"
#              (section 35: Clear_Light_of_Bliss_Text_2019-08-34.xhtml)
#      Sample: "aggregates:"
#              (section 35: Clear_Light_of_Bliss_Text_2019-08-34.xhtml)
#
#   📌 _idGenObjectStyle-Disabled
#      Count: 30 | In 30 sections | Tags: div(30)
#      Sample: "Vajradhara"
#              (section 11: Clear_Light_of_Bliss_Text_2019-08-10.xhtml)
#      Sample: "Manjushri"
#              (section 13: Clear_Light_of_Bliss_Text_2019-08-12.xhtml)
#
#   📌 Normal
#      Count: 28 | In 8 sections | Tags: span(28)
#      Sample: "THE MAHAMUDRA OF THE ORAL LINEAGE OF THE UNEQUALLED VIRTUOUS TRADITION"
#              (section 68: Clear_Light_of_Bliss_Text_2019-08-67.xhtml)
#      Sample: "CONTENTS"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#
#   📌 _1---Hyperlink
#      Count: 27 | In 3 sections | Tags: span(27)
#      Sample: "www.tharpa.com"
#              (section 2: Clear_Light_of_Bliss_Text_2019-08-1.xhtml)
#      Sample: "tharpa.co"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#
#   📌 line-drawings
#      Count: 27 | In 27 sections | Tags: div(27)
#      Sample: "Vajradhara"
#              (section 11: Clear_Light_of_Bliss_Text_2019-08-10.xhtml)
#      Sample: "Manjushri"
#              (section 13: Clear_Light_of_Bliss_Text_2019-08-12.xhtml)
#
#   📌 Also-by-other-title
#      Count: 23 | In 1 sections | Tags: p(23)
#      Sample: "How to Transform Your Life"
#              (section 3: Clear_Light_of_Bliss_Text_2019-08-2.xhtml)
#      Sample: "How to Understand the Mind"
#              (section 3: Clear_Light_of_Bliss_Text_2019-08-2.xhtml)
#
#   📌 Tharpa-Offices-Address-Title
#      Count: 18 | In 1 sections | Tags: p(18)
#      Sample: "Tharpa UK"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#      Sample: "Tharpa US"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#
#   📌 Tharpa-Offices-Address-Last
#      Count: 18 | In 1 sections | Tags: p(18)
#      Sample: "Email:info.uk@tharpa.com"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#      Sample: "Email:info.us@tharpa.com"
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#
#   📌 Study-program-center-address
#      Count: 17 | In 1 sections | Tags: p(17)
#      Sample: "NKT-IKBUCentral Office"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "Conishead Priory"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Editorial-info
#      Count: 12 | In 2 sections | Tags: p(12)
#      Sample: "This digital edition published 2019"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#      Sample: "The right of Geshe Kelsang Gyatso to be identified as author of this work has been asserted by him in accordance with th..."
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#
#   📌 Editorial-info-no-space-below
#      Count: 7 | In 1 sections | Tags: p(7)
#      Sample: "Second edition totally reset and revised 1992 - 3 Impressions"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#      Sample: "Third edition reset and revised 2014 - Impression 2 (2019)"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#
#   📌 Small-Caps-Italic
#      Count: 7 | In 2 sections | Tags: span(7)
#      Sample: "HUM"
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#      Sample: "HUM"
#              (section 14: Clear_Light_of_Bliss_Text_2019-08-13.xhtml)
#
#   📌 Editorial-info-addresses
#      Count: 6 | In 1 sections | Tags: p(6)
#      Sample: "Tharpa Publications UK"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#      Sample: "Conishead Priory"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#
#   📌 Study-program-text-space-below
#      Count: 6 | In 1 sections | Tags: p(6)
#      Sample: "The Foundation Programme provides an opportunity to deepen our understanding and experience of Buddhism through a system..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "The benefits of studying and practising these texts are as follows:"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Sadhana-prose-space-below
#      Count: 5 | In 1 sections | Tags: p(5)
#      Sample: "Due to my making requests in this way, all the Buddhas of the ten directions dissolve into Je Tsongkhapa who is insepara..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "In the vast space of emptiness of all phenomena, the nature of my purified mistaken appearance of all phenomena – which ..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Sadhana-instruction-full-space-below
#      Count: 4 | In 2 sections | Tags: p(4)
#      Sample: "At this point we imagine that wisdom being Je Tsongkhapa together with his retinue dissolves into the assembly of Guru S..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#      Sample: "We meditate on this belief single-pointedly. This meditation is called ‘training in definitive Guru yoga’. We should rep..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Biblio-text
#      Count: 4 | In 1 sections | Tags: p(4)
#      Sample: "Geshe Kelsang Gyatso is a highly respected meditation master and scholar of the Mahayana Buddhist tradition founded by J..."
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#      Sample: "The following books by Geshe Kelsang are all published by Tharpa Publications."
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#
#   📌 Biblio-title-entry
#      Count: 4 | In 2 sections | Tags: p(4)
#      Sample: "Books"
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#      Sample: "Sadhanas and Other Booklets"
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#
#   📌 Study-program-text-full-space-below
#      Count: 4 | In 1 sections | Tags: p(4)
#      Sample: "The General Programme provides a basic introduction to Buddhist view, meditation and practice that is suitable for begin..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "(6)How to Understand the Mind– we understand the relationship between our mind and its external objects. If we understan..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Profits
#      Count: 4 | In 1 sections | Tags: p(4)
#      Sample: "NKT-IKBU International Temples Project"
#              (section 86: Clear_Light_of_Bliss_Text_2019-08-85.xhtml)
#      Sample: "and the profit from its sale is designated for public benefit through this fund."
#              (section 86: Clear_Light_of_Bliss_Text_2019-08-85.xhtml)
#
#   📌 _1---Small-Caps---BOLD
#      Count: 3 | In 1 sections | Tags: span(3)
#      Sample: "GENERAL PROGRAMME"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "FOUNDATION PROGRAMME"
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Tharpa-logo-country
#      Count: 2 | In 1 sections | Tags: p(2)
#      Sample: "UK • US • CANADA"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#      Sample: "AUSTRALIA • ASIA"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 Sadhana-content-level-2 [Level 2]
#      Count: 2 | In 1 sections | Tags: p(2)
#      Sample: "Liberating Prayer"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#      Sample: "The Yoga of Buddha Heruka"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#
#   📌 Sadhana-content-level-3 [Level 3]
#      Count: 2 | In 1 sections | Tags: p(2)
#      Sample: "Praise to Buddha Shakyamuni"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#      Sample: "The essential self-generation sadhana of Heruka body mandala & Condensed Six-session Yoga"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#
#   📌 Study-program-text
#      Count: 2 | In 1 sections | Tags: p(2)
#      Sample: "Kadampa Buddhism is a Mahayana Buddhist school founded by the great Indian Buddhist Master Atisha (AD982-1054). His foll..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#      Sample: "The Teacher Training Programme is designed for people who wish to train as authentic Dharma Teachers. In addition to com..."
#              (section 82: Clear_Light_of_Bliss_Text_2019-08-81.xhtml)
#
#   📌 Book-Title-inside
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Clear Light of Bliss"
#              (section 1: Clear_Light_of_Bliss_Text_2019-08.xhtml)
#
#   📌 Also-by
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Suggested study or reading order for beginners of books by Venerable Geshe Kelsang Gyatso Rinpoche"
#              (section 3: Clear_Light_of_Bliss_Text_2019-08-2.xhtml)
#
#   📌 Author
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Venerable Geshe Kelsang Gyatso Rinpoche"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 Book-title-title-page
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Clear Light of Bliss"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 Chapter-subtitle
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "TANTRIC MEDITATION MANUAL"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 Tharpa-logo
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "THARPA PUBLICATIONS"
#              (section 4: Clear_Light_of_Bliss_Text_2019-08-3.xhtml)
#
#   📌 Editorial-info-no-space-below-1st
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "First published in 1982 by Wisdom Publications"
#              (section 5: Clear_Light_of_Bliss_Text_2019-08-4.xhtml)
#
#   📌 line-drawings-no-page-before-and-after
#      Count: 1 | In 1 sections | Tags: div(1)
#
#   📌 Sadhana-content-level-2-space-after [Level 2]
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Prayers of Request to the MahamudraLineage Gurus"
#              (section 70: Clear_Light_of_Bliss_Text_2019-08-69.xhtml)
#
#   📌 Sadhana-prose-full-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "In the space before me is Guru Sumati Buddha Heruka – Je Tsongkhapa inseparable from my root Guru, Buddha Shakyamuni and..."
#              (section 77: Clear_Light_of_Bliss_Text_2019-08-76.xhtml)
#
#   📌 Mantra
#      Count: 1 | In 1 sections | Tags: span(1)
#
#   📌 Biblio-entry-2-lines-full-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Universal CompassionInspiring solutions for difficult times. (4th. edn., 2002)"
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#
#   📌 Biblio-entry-2-lines-space-below
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "The Yoga of White Tara, Buddha of Long Life."
#              (section 81: Clear_Light_of_Bliss_Text_2019-08-80.xhtml)
#
#   📌 Tharpa-Offices-Text
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "Tharpa books are currently published in English (UK and US), Chinese, French, German, Italian, Japanese, Portuguese and ..."
#              (section 83: Clear_Light_of_Bliss_Text_2019-08-82.xhtml)
#
#   📌 Profits-top
#      Count: 1 | In 1 sections | Tags: p(1)
#      Sample: "This eBook is published under the auspices of the"
#              (section 86: Clear_Light_of_Bliss_Text_2019-08-85.xhtml)

# %% [markdown]
# ## Phase 0 Answers
#
# These are the critical questions we need answered before re-extraction.

# %%
print("=" * 70)
print("PHASE 0 ANSWERS")
print("=" * 70)

print("\n1. CHAPTER TITLE CLASSES:")
if 'CHAPTER_TITLE' in classified:
    for info in classified['CHAPTER_TITLE']:
        print(f"   → {info['class_name']} (used {info['count']} times)")
        for s in info['samples'][:2]:
            print(f'     e.g., "{s["text"]}"')
else:
    print("   ⚠️  No classes matched 'chapter-title' pattern!")
    print("   Check UNKNOWN classes for possible chapter headings.")

print("\n2. SECTION HEADING CLASSES:")
if 'SECTION_HEADING' in classified:
    for info in classified['SECTION_HEADING']:
        print(f"   → {info['class_name']} (used {info['count']} times)")
        for s in info['samples'][:2]:
            print(f'     e.g., "{s["text"]}"')
else:
    print("   ⚠️  No classes matched section heading pattern!")

print("\n3. BODY PARAGRAPH CLASSES:")
body_classes = classified.get('BODY_FIRST_PARA', []) + classified.get('BODY_TEXT', [])
if body_classes:
    for info in sorted(body_classes, key=lambda x: -x['count']):
        print(f"   → {info['class_name']} (used {info['count']} times)")
else:
    print("   ⚠️  No body text classes found!")

print("\n4. HEADING LEVELS DETECTED:")
all_levels = set()
for role in ['CHAPTER_TITLE', 'PART_TITLE', 'SECTION_HEADING', 'HEADING_OTHER']:
    for info in classified.get(role, []):
        if info['heading_level'] is not None:
            all_levels.add((info['heading_level'], info['class_name']))
if all_levels:
    for level, cls in sorted(all_levels):
        print(f"   Level {level}: {cls}")
else:
    print("   ⚠️  No numeric heading levels detected in class names")

print("\n5. UNKNOWN/UNCLASSIFIED CLASSES (review these!):")
if 'UNKNOWN' in classified:
    for info in classified['UNKNOWN']:
        print(f"   → {info['class_name']} (used {info['count']} times)")
        for s in info['samples'][:1]:
            print(f'     e.g., "{s["text"]}"')
else:
    print("   ✓ All classes classified!")
# Out:
# ======================================================================
# PHASE 0 ANSWERS
# ======================================================================
#
# 1. CHAPTER TITLE CLASSES:
#    → Chapter-title-TOC-Level-1 (used 30 times)
#      e.g., "About the Author"
#      e.g., "Contents"
#    → Chapter-title-TOC-Level-2 (used 4 times)
#      e.g., "The Condensed Meaning of the Text"
#      e.g., "Prayers of Request to the Mahamudra Lineage Gurus"
#    → Chapter-title-TOC-Level-1-no-new-page (used 2 times)
#      e.g., "Foreword"
#      e.g., "Study Programmes of Kadampa Buddhism"
#
# 2. SECTION HEADING CLASSES:
#    → Index-Section-Head (used 23 times)
#      e.g., "A"
#      e.g., "B"
#
# 3. BODY PARAGRAPH CLASSES:
#    → Text-2nd-para (used 383 times)
#    → Text-1st-para-space-below (used 101 times)
#    → Text-1st-para (used 100 times)
#    → Text-list-10-to-99-with-parenthesis-middle (used 92 times)
#    → Text-list-1-to-9-middle (used 86 times)
#    → Text-list-1-to-9-last-full-space-below (used 59 times)
#    → Text-list-1-to-9-with-parenthesis-middle (used 58 times)
#    → Text-2nd-para-full-space-below (used 58 times)
#    → Text-list-1-to-9-begin (used 49 times)
#    → Text-1st-para-full-space-below (used 47 times)
#    → Text-quotation-verse-middle (used 44 times)
#    → Text-2nd-para-space-below (used 38 times)
#    → TOC-Body-Text (used 32 times)
#    → Text-list-1-to-9-with-parenthesis-begin (used 26 times)
#    → Text-quotation-verse-italic-begin (used 15 times)
#    → Text-quotation-prose-single (used 15 times)
#    → Text-list-10-to-99-with-parenthesis-last (used 15 times)
#    → Text-quotation-verse-italic-middle (used 12 times)
#    → Text-list-1-to-9-with-parenthesis-last (used 12 times)
#    → Text-Signature-Author-2-lines-plus (used 9 times)
#    → Text-quotation-verse-last (used 7 times)
#    → Sadhana-instruction-middle-para (used 6 times)
#    → Text-quotation-verse-italic-last (used 4 times)
#    → Text-quotation-verse-begin (used 4 times)
#    → Text-list-1-to-9-last (used 4 times)
#    → Text-title-2 (used 4 times)
#    → Study-program-text-2nd-para (used 4 times)
#    → Sadhana-instruction-first-para (used 3 times)
#    → Text-quotation-prose-single-last (used 3 times)
#    → Sadhana-instruction-last-para (used 3 times)
#    → Text-quotation-verse-single (used 2 times)
#    → Text-quotation-prose-single-full-space-below (used 2 times)
#    → Text-list-1-to-9-with-parenthesis-last-full-space-below (used 2 times)
#    → Study-program-text-2nd-para-full-space-below (used 2 times)
#    → Text-quotation-verse-italic-last-full-space-below (used 1 times)
#    → Text-quotation-verse-italic-single (used 1 times)
#    → Text-quotation-verse-last-full-space-below (used 1 times)
#
# 4. HEADING LEVELS DETECTED:
#    Level 1: Chapter-title-TOC-Level-1
#    Level 1: Chapter-title-TOC-Level-1-no-new-page
#    Level 1: Text-heading-1
#    Level 2: Chapter-title-TOC-Level-2
#    Level 2: Sadhana-heading-2
#    Level 3: Sadhana-heading-3
#    Level 4: Sadhana-heading-4
#
# 5. UNKNOWN/UNCLASSIFIED CLASSES (review these!):
#    → Italic (used 520 times)
#      e.g., "included at the request of faithful disciples"
#    → Bold-Italic (used 236 times)
#      e.g., "Migtsema"
#    → Small-Caps (used 135 times)
#      e.g., "OM"
#    → Tharpa-Offices-Address (used 87 times)
#      e.g., "Conishead Priory,"
#    → Biblio-entry-2-lines (used 73 times)
#      e.g., "The Bodhisattva VowA practical guide to helping others. (2nd. edn., 1995)"
#    → Basic-Text-Frame (used 64 times)
#      e.g., "Suggested study or reading order for beginners of books by Venerable Geshe Kelsang Gyatso RinpocheHow to Transform Your ..."
#    → ebook-page-break (used 48 times)
#      e.g., "page break"
#    → Bold (used 35 times)
#      e.g., "The five"
#    → _idGenObjectStyle-Disabled (used 30 times)
#      e.g., "Vajradhara"
#    → Normal (used 28 times)
#      e.g., "THE MAHAMUDRA OF THE ORAL LINEAGE OF THE UNEQUALLED VIRTUOUS TRADITION"
#    → _1---Hyperlink (used 27 times)
#      e.g., "www.tharpa.com"
#    → line-drawings (used 27 times)
#      e.g., "Vajradhara"
#    → Also-by-other-title (used 23 times)
#      e.g., "How to Transform Your Life"
#    → Tharpa-Offices-Address-Title (used 18 times)
#      e.g., "Tharpa UK"
#    → Tharpa-Offices-Address-Last (used 18 times)
#      e.g., "Email:info.uk@tharpa.com"
#    → Study-program-center-address (used 17 times)
#      e.g., "NKT-IKBUCentral Office"
#    → Editorial-info (used 12 times)
#      e.g., "This digital edition published 2019"
#    → Editorial-info-no-space-below (used 7 times)
#      e.g., "Second edition totally reset and revised 1992 - 3 Impressions"
#    → Small-Caps-Italic (used 7 times)
#      e.g., "HUM"
#    → Editorial-info-addresses (used 6 times)
#      e.g., "Tharpa Publications UK"
#    → Study-program-text-space-below (used 6 times)
#      e.g., "The Foundation Programme provides an opportunity to deepen our understanding and experience of Buddhism through a system..."
#    → Sadhana-prose-space-below (used 5 times)
#      e.g., "Due to my making requests in this way, all the Buddhas of the ten directions dissolve into Je Tsongkhapa who is insepara..."
#    → Sadhana-instruction-full-space-below (used 4 times)
#      e.g., "At this point we imagine that wisdom being Je Tsongkhapa together with his retinue dissolves into the assembly of Guru S..."
#    → Biblio-text (used 4 times)
#      e.g., "Geshe Kelsang Gyatso is a highly respected meditation master and scholar of the Mahayana Buddhist tradition founded by J..."
#    → Biblio-title-entry (used 4 times)
#      e.g., "Books"
#    → Study-program-text-full-space-below (used 4 times)
#      e.g., "The General Programme provides a basic introduction to Buddhist view, meditation and practice that is suitable for begin..."
#    → Profits (used 4 times)
#      e.g., "NKT-IKBU International Temples Project"
#    → _1---Small-Caps---BOLD (used 3 times)
#      e.g., "GENERAL PROGRAMME"
#    → Tharpa-logo-country (used 2 times)
#      e.g., "UK • US • CANADA"
#    → Sadhana-content-level-2 (used 2 times)
#      e.g., "Liberating Prayer"
#    → Sadhana-content-level-3 (used 2 times)
#      e.g., "Praise to Buddha Shakyamuni"
#    → Study-program-text (used 2 times)
#      e.g., "Kadampa Buddhism is a Mahayana Buddhist school founded by the great Indian Buddhist Master Atisha (AD982-1054). His foll..."
#    → Book-Title-inside (used 1 times)
#      e.g., "Clear Light of Bliss"
#    → Also-by (used 1 times)
#      e.g., "Suggested study or reading order for beginners of books by Venerable Geshe Kelsang Gyatso Rinpoche"
#    → Author (used 1 times)
#      e.g., "Venerable Geshe Kelsang Gyatso Rinpoche"
#    → Book-title-title-page (used 1 times)
#      e.g., "Clear Light of Bliss"
#    → Chapter-subtitle (used 1 times)
#      e.g., "TANTRIC MEDITATION MANUAL"
#    → Tharpa-logo (used 1 times)
#      e.g., "THARPA PUBLICATIONS"
#    → Editorial-info-no-space-below-1st (used 1 times)
#      e.g., "First published in 1982 by Wisdom Publications"
#    → line-drawings-no-page-before-and-after (used 1 times)
#    → Sadhana-content-level-2-space-after (used 1 times)
#      e.g., "Prayers of Request to the MahamudraLineage Gurus"
#    → Sadhana-prose-full-space-below (used 1 times)
#      e.g., "In the space before me is Guru Sumati Buddha Heruka – Je Tsongkhapa inseparable from my root Guru, Buddha Shakyamuni and..."
#    → Mantra (used 1 times)
#    → Biblio-entry-2-lines-full-space-below (used 1 times)
#      e.g., "Universal CompassionInspiring solutions for difficult times. (4th. edn., 2002)"
#    → Biblio-entry-2-lines-space-below (used 1 times)
#      e.g., "The Yoga of White Tara, Buddha of Long Life."
#    → Tharpa-Offices-Text (used 1 times)
#      e.g., "Tharpa books are currently published in English (UK and US), Chinese, French, German, Italian, Japanese, Portuguese and ..."
#    → Profits-top (used 1 times)
#      e.g., "This eBook is published under the auspices of the"

# %% [markdown]
# ## Save Inventory to JSON

# %%
output = {
    'epub_file': EPUB_FILE,
    'epub_path': EPUB_PATH,
    'total_sections': len(items),
    'total_unique_classes': len(class_counter),
    'html_tags_used': dict(all_tags_used.most_common()),
    'class_inventory': {},
    'classes_by_role': {},
    'phase0_answers': {
        'chapter_title_classes': [i['class_name'] for i in classified.get('CHAPTER_TITLE', [])],
        'section_heading_classes': [i['class_name'] for i in classified.get('SECTION_HEADING', [])],
        'body_text_classes': [i['class_name'] for i in 
                              classified.get('BODY_TEXT', []) + classified.get('BODY_FIRST_PARA', [])],
        'heading_levels': {str(level): cls for level, cls in sorted(all_levels)} if all_levels else {},
    }
}

# Full inventory
for cls, count in class_counter.most_common():
    role = classify_css_role(cls)
    output['class_inventory'][cls] = {
        'count': count,
        'role': role,
        'heading_level': extract_heading_level(cls),
        'tags': [t for t in class_by_tag if cls in class_by_tag[t]],
        'sections_count': len(class_sections[cls]),
        'samples': [s['text'] for s in class_samples.get(cls, [])]
    }

# Grouped by role
for role, items_list in classified.items():
    output['classes_by_role'][role] = [
        {'class': i['class_name'], 'count': i['count'], 'level': i['heading_level']}
        for i in items_list
    ]

with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print(f"✓ Saved to {OUTPUT_FILE}")
print(f"  {len(output['class_inventory'])} classes documented")
# Out:
# ✓ Saved to 00_css_class_inventory.json
#   121 classes documented

# %% [markdown]
# ## 🚦 Validation Gate 0
#
# Must pass ALL checks before proceeding to re-extraction.

# %%
print("=" * 70)
print("🚦 VALIDATION GATE 0")
print("=" * 70)

checks = [
    ('Chapter title CSS classes identified', len(classified.get('CHAPTER_TITLE', [])) > 0),
    ('Section heading CSS classes identified', len(classified.get('SECTION_HEADING', [])) > 0),
    ('Body text CSS classes identified', len(body_classes) > 0),
    ('Heading levels detected', len(all_levels) > 0),
]

all_pass = True
for desc, passed in checks:
    status = "✓" if passed else "✗"
    if not passed:
        all_pass = False
    print(f"  {status} {desc}")

if all_pass:
    print(f"\n  ✅ ALL CHECKS PASSED - Ready to proceed to re-extraction!")
else:
    print(f"\n  ⚠️  SOME CHECKS FAILED")
    print(f"  Review the UNKNOWN classes above — the heading patterns may")
    print(f"  use different naming than expected.")
    print(f"\n  → Paste the output from this notebook into Claude")
    print(f"    and we'll map the classes together.")
# Out:
# ======================================================================
# 🚦 VALIDATION GATE 0
# ======================================================================
#   ✓ Chapter title CSS classes identified
#   ✓ Section heading CSS classes identified
#   ✓ Body text CSS classes identified
#   ✓ Heading levels detected
#
#   ✅ ALL CHECKS PASSED - Ready to proceed to re-extraction!
